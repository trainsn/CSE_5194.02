# %%
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
# 设置图例字号
mpl.rcParams['legend.fontsize'] = 10
fig = plt.figure(figsize=(20, 20))

# 设置三维图形模式
ax = fig.gca(projection='3d')

# 测试数据
theta = np.linspace(-4 * np.pi, 4 * np.pi, 100)
z = np.linspace(-4, 4, 100) / 4
r = z**3 + 1
x = r * np.sin(theta)
y = r * np.cos(theta)

# 绘制图形
num_lines = 100
for i in range(num_lines):
    linePoints = np.load("Euler/streamline" + str(i) + ".npy")
    ax.plot(linePoints[:, 0], linePoints[:, 1], linePoints[:, 2], "blue")

# 显示图例
ax.legend()

# 显示图形
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
# 设置图例字号
mpl.rcParams['legend.fontsize'] = 10
fig = plt.figure(figsize=(20, 20))

# 设置三维图形模式
ax = fig.gca(projection='3d')

# 测试数据
theta = np.linspace(-4 * np.pi, 4 * np.pi, 100)
z = np.linspace(-4, 4, 100) / 4
r = z**3 + 1
x = r * np.sin(theta)
y = r * np.cos(theta)

# 绘制图形
num_lines = 100
for i in range(num_lines):
    linePoints = np.load("RK4/streamline" + str(i) + ".npy")
    ax.plot(linePoints[:, 0], linePoints[:, 1], linePoints[:, 2], "blue")

# 显示图例
ax.legend()

# 显示图形
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
img = Image.open('tornado_vorticity_512_vp(0_90)_phong0.png')

plt.figure(figsize=(4, 4)) # 图像窗口名称
plt.imshow(img)
plt.axis('off') 
plt.title('vp(0_90)') # 图像题目
plt.show()

# %%
img = Image.open('tornado_vorticity_512_vp(90_90)_phong0.png')

plt.figure(figsize=(4, 4)) # 图像窗口名称
plt.imshow(img)
plt.axis('off') 
plt.title('vp(90_90)') # 图像题目
plt.show()

# %%
img = Image.open('tornado_vorticity_512_vp(180_0)_phong0.png')

plt.figure(figsize=(4, 4)) # 图像窗口名称
plt.imshow(img)
plt.axis('off') 
plt.title('vp(180_0)') # 图像题目
plt.show()
